# %% [markdown]
# #Downloading Dataset... ✅

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = '/content'

# %%
# !kaggle competitions download -c house-prices-advanced-regression-techniques
# Out:
# ...
# 100% 199k/199k [00:00<00:00, 713kB/s]
# 100% 199k/199k [00:00<00:00, 712kB/s]

# %%
#extracting...
import zipfile
zip_ref = zipfile.ZipFile('/content/house-prices-advanced-regression-techniques.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %% [markdown]
# #Importing Packages.. ✅

# %%
import pandas as pd
import sklearn
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error as mse

# %%
train_df=pd.read_csv('/content/train.csv')
test_df=pd.read_csv('/content/test.csv')

# %%
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# #So we need to Predict the prices of the house using above data which the help of `Square footage,no.of bedroom and bathroom`.

# %%
train_df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
data_train=train_df[['LotArea','FullBath','HalfBath','BedroomAbvGr','SalePrice']]

data_test=test_df[['LotArea','FullBath','HalfBath','BedroomAbvGr']]

# %%
data_train.isna().sum() # finds the no.of null/empty cell
# Out:
# LotArea         0
# FullBath        0
# HalfBath        0
# BedroomAbvGr    0
# SalePrice       0
# dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(data_train.drop('SalePrice',axis=1),data_train['SalePrice'],test_size=0.2,random_state=42)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.4237271176884789

# %%
y_pred=model.predict(x_test)

# %%
model.score(x_test,y_test)
# Out:
# 0.4237271176884789

# %%
#Data Visualising..
plt.scatter(y_test,y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.show()
